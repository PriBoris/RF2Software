# %%
import scipy as sp
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0.0, 1.0, 0.001)

# %%
z = 2*(x-0.5)
y2 = 1-z**2
y3 = 1-z**3
y4 = 1-z**4
y5 = 1-z**5
y6 = 1-z**6

# %%
plt.plot(x,y2,x,y3,x,y4,x,y5,x,y6)
plt.grid(True)
plt.axis([0, 1, 0, 1])
plt.show()
